# %%
##Importing IMDB Dataset and cleaning reviews

#Importing libraries
import nltk
import pandas as pd
import re
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from bs4 import BeautifulSoup

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\merhbaa\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\merhbaa\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#Importing dataset and replacing labels with 0 and 1 for classification
df = pd.read_csv('IMDB Dataset.csv', encoding = 'Latin-1')
df['sentiment'] = df['sentiment'].map({'positive': 1, 'negative': 0})

# %%
df
# Out:
#                                                   review  sentiment
# 0      One of the other reviewers has mentioned that ...          1
# 1      A wonderful little production. <br /><br />The...          1
# 2      I thought this was a wonderful way to spend ti...          1
# 3      Basically there's a family where a little boy ...          0
# 4      Petter Mattei's "Love in the Time of Money" is...          1
# ...                                                  ...        ...
# 49995  I thought this movie did a down right good job...          1
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...          0
# 49997  I am a Catholic taught in parochial elementary...          0
# 49998  I'm going to have to disagree with the previou...          0
# 49999  No one expects the Star Trek movies to be high...          0
#
# [50000 rows x 2 columns]

# %%
df['review'][0]
# Out:
# "One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the fact that it goes where other shows wouldn't dare. Forget pretty pictures painted for mainstream audiences, forget charm, forget romance...OZ doesn't mess around. The first episode I ever saw struck me as so nasty it was surreal, I couldn't say I was ready for it, but as I watched more, I developed a taste for Oz, and got accustomed to the high levels of graphic violence. Not just violence, but injustice (crooked guards who'll be sold out for a nickel, inmates who'll kill on order and get away with it, well mannered, middle class inmates being turned into prison bitches due to their lack of street skills or prison experience) Watching Oz, you may become comfortable with what is uncomfortable viewing....thats if you can get in touch with your darker side."

# %%
#Defining stop_words and lemmatizer
stop_words = set(stopwords.words("english")) 
lemmatizer = WordNetLemmatizer()

# %%
#Removing the html strips
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

# %%
#Defining clean_text function
def clean_text(text):
    text = strip_html(text)
    text = re.sub(r'[^A-Za-z0-9]+',' ',text)
    text = text.lower()
    text = [lemmatizer.lemmatize(token) for token in text.split(" ")]
    text = [lemmatizer.lemmatize(token, "v") for token in text]
    text = [word for word in text if not word in stop_words]
    text = " ".join(text)
    return text

# %%
#Creating new column for processed reviews
df['Processed_Reviews'] = df.review.apply(lambda x: clean_text(x))

# %%
df
# Out:
#                                                   review  sentiment  \
# 0      One of the other reviewers has mentioned that ...          1
# 1      A wonderful little production. <br /><br />The...          1
# 2      I thought this was a wonderful way to spend ti...          1
# 3      Basically there's a family where a little boy ...          0
# 4      Petter Mattei's "Love in the Time of Money" is...          1
# ...                                                  ...        ...
# 49995  I thought this movie did a down right good job...          1
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...          0
# 49997  I am a Catholic taught in parochial elementary...          0
# 49998  I'm going to have to disagree with the previou...          0
# 49999  No one expects the Star Trek movies to be high...          0
#
#                                        Processed_Reviews
# 0      one reviewer ha mention watch 1 oz episode hoo...
# 1      wonderful little production film technique una...
# 2      think wa wonderful way spend time hot summer w...
# 3      basically family little boy jake think zombie ...
# 4      petter mattei love time money visually stun fi...
# ...                                                  ...
# 49995  think movie right good job creative original f...
# 49996  bad plot bad dialogue bad act idiotic direct a...
# 49997  catholic teach parochial elementary school nun...
# 49998  go disagree previous comment side maltin one s...
# 49999  one expect star trek movie high art fan expect...
#
# [50000 rows x 3 columns]

# %%
df['Processed_Reviews'][0]
# Out:
# 'one reviewer ha mention watch 1 oz episode hook right exactly happen first thing strike oz wa brutality unflinching scene violence set right word go trust show faint hearted timid show pull punch regard drug sex violence hardcore classic use word call oz nickname give oswald maximum security state penitentary focus mainly emerald city experimental section prison cell glass front face inwards privacy high agenda em city home many aryan muslim gangsta latino christian italian irish scuffle death stare dodgy deal shady agreement never far away would say main appeal show due fact go show dare forget pretty picture paint mainstream audience forget charm forget romance oz mess around first episode ever saw strike nasty wa surreal say wa ready watch develop taste oz get accustom high level graphic violence violence injustice crook guard sell nickel inmate kill order get away well mannered middle class inmate turn prison bitch due lack street skill prison experience watch oz may become comfortable uncomfortable view thats get touch darker side '

# %% [markdown]
# # Training

# %%
##Deploying SVM model on available data

#Importing libraries
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import pickle

# %%
#Defining input and target variable
x = df['Processed_Reviews']
y = df['sentiment']

# %%
#Training and splitting
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
#Vectorization and Bag of words method with default parameters
count_vect = CountVectorizer().fit(df['Processed_Reviews'].values.astype('U'))
bow_train = count_vect.transform(X_train.values.astype('U'))
bow_test = count_vect.transform(X_test.values.astype('U'))

# %%
bow_train.shape
# Out:
# (40000, 83866)

# %%
#instantiate the model (using the default parameters)
SVM = SVC()

# %%
# fit the model with pre-processed data
SVM.fit(bow_train, y_train)
# Out:
# SVC()

# %%
#perform classification and prediction on samples in tf_test
predicted_SVM = SVM.predict(bow_test)
print(classification_report(y_test, predicted_SVM))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87      5035
#            1       0.86      0.89      0.87      4965
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000

# %% [markdown]
# # gridSearch

# %%
#Importing libraries
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import cross_val_score

# %%
#Creating a Pipeline
pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('SVM', SVC())
])

# %%
#Defining hyperparameters
parameters = {
    'vect__max_df':[0.3,0.4,0.5,0.6,0.7],
    'vect__ngram_range':  [(1,1), (1,2), (1,3)],
    'SVM__kernel': ['poly', 'rbf', 'sigmoid'],
    'SVM__C': [50, 10, 1.0]}

# %%
# define grid search
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(pipeline, param_grid=parameters, refit = True, verbose = 3)
grid_result = grid_search.fit(df.loc[:7000, 'Processed_Reviews'].values.astype('U'), df.loc[:7000, 'sentiment'].values.astype('U'))
# Out:
# Fitting 5 folds for each of 135 candidates, totalling 675 fits
# [CV 1/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.3, vect__ngram_range=(1, 1);, score=0.770 total time= 1.0min
# [CV 2/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.3, vect__ngram_range=(1, 1);, score=0.793 total time= 1.0min
# [CV 3/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.3, vect__ngram_range=(1, 1);, score=0.731 total time= 1.0min
# [CV 4/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.3, vect__ngram_range=(1, 1);, score=0.791 total time= 1.0min
# [CV 5/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.3, vect__ngram_range=(1, 1);, score=0.764 total time=  51.4s
# [CV 1/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.3, vect__ngram_range=(1, 2);, score=0.652 total time= 1.8min
# [CV 2/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.3, vect__ngram_range=(1, 2);, score=0.676 total time= 1.6min
# [CV 3/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.3, vect__ngram_range=(1, 2);, score=0.630 total time= 1.6min
# [CV 4/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.3, vect__ngram_range=(1, 2);, score=0.670 total time= 1.9min
# [CV 5/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.3, vect__ngram_range=(1, 2);, score=0.639 total time= 1.6min
# [CV 1/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.3, vect__ngram_range=(1, 3);, score=0.575 total time= 2.2min
# [CV 2/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.3, vect__ngram_range=(1, 3);, score=0.601 total time= 2.2min
# [CV 3/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.3, vect__ngram_range=(1, 3);, score=0.566 total time= 2.2min
# [CV 4/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.3, vect__ngram_range=(1, 3);, score=0.596 total time= 2.1min
# [CV 5/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.3, vect__ngram_range=(1, 3);, score=0.576 total time= 2.2min
# [CV 1/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.4, vect__ngram_range=(1, 1);, score=0.775 total time= 1.0min
# [CV 2/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.4, vect__ngram_range=(1, 1);, score=0.775 total time= 1.0min
# [CV 3/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.4, vect__ngram_range=(1, 1);, score=0.737 total time=  51.7s
# [CV 4/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.4, vect__ngram_range=(1, 1);, score=0.798 total time= 1.0min
# [CV 5/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.4, vect__ngram_range=(1, 1);, score=0.773 total time= 1.0min
# [CV 1/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.4, vect__ngram_range=(1, 2);, score=0.682 total time= 1.8min
# [CV 2/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.4, vect__ngram_range=(1, 2);, score=0.700 total time= 1.8min
# [CV 3/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.4, vect__ngram_range=(1, 2);, score=0.659 total time= 1.6min
# [CV 4/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.4, vect__ngram_range=(1, 2);, score=0.701 total time= 1.6min
# [CV 5/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.4, vect__ngram_range=(1, 2);, score=0.671 total time= 1.6min
# [CV 1/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.4, vect__ngram_range=(1, 3);, score=0.608 total time= 2.2min
# [CV 2/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.4, vect__ngram_range=(1, 3);, score=0.627 total time= 2.2min
# [CV 3/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.4, vect__ngram_range=(1, 3);, score=0.594 total time= 2.2min
# [CV 4/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.4, vect__ngram_range=(1, 3);, score=0.626 total time= 2.1min
# [CV 5/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.4, vect__ngram_range=(1, 3);, score=0.602 total time= 2.1min
# [CV 1/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.5, vect__ngram_range=(1, 1);, score=0.777 total time= 1.0min
# [CV 2/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.5, vect__ngram_range=(1, 1);, score=0.789 total time= 1.0min
# [CV 3/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.5, vect__ngram_range=(1, 1);, score=0.743 total time= 1.0min
# [CV 4/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.5, vect__ngram_range=(1, 1);, score=0.800 total time= 1.0min
# [CV 5/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.5, vect__ngram_range=(1, 1);, score=0.779 total time= 1.0min
# [CV 1/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.5, vect__ngram_range=(1, 2);, score=0.698 total time= 1.8min
# [CV 2/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.5, vect__ngram_range=(1, 2);, score=0.719 total time= 1.8min
# [CV 3/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.5, vect__ngram_range=(1, 2);, score=0.666 total time= 1.6min
# [CV 4/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.5, vect__ngram_range=(1, 2);, score=0.728 total time= 1.6min
# [CV 5/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.5, vect__ngram_range=(1, 2);, score=0.687 total time= 1.6min
# [CV 1/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.5, vect__ngram_range=(1, 3);, score=0.622 total time= 2.5min
# [CV 2/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.5, vect__ngram_range=(1, 3);, score=0.646 total time= 2.2min
# [CV 3/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.5, vect__ngram_range=(1, 3);, score=0.604 total time= 2.2min
# [CV 4/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.5, vect__ngram_range=(1, 3);, score=0.651 total time= 2.2min
# [CV 5/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.5, vect__ngram_range=(1, 3);, score=0.620 total time= 2.2min
# [CV 1/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.6, vect__ngram_range=(1, 1);, score=0.781 total time= 1.0min
# [CV 2/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.6, vect__ngram_range=(1, 1);, score=0.802 total time= 1.0min
# [CV 3/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.6, vect__ngram_range=(1, 1);, score=0.741 total time=  51.0s
# [CV 4/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.6, vect__ngram_range=(1, 1);, score=0.816 total time= 1.1min
# [CV 5/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.6, vect__ngram_range=(1, 1);, score=0.789 total time= 1.0min
# [CV 1/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.6, vect__ngram_range=(1, 2);, score=0.718 total time= 1.9min
# [CV 2/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.6, vect__ngram_range=(1, 2);, score=0.740 total time= 1.9min
# [CV 3/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.6, vect__ngram_range=(1, 2);, score=0.681 total time= 1.9min
# [CV 4/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.6, vect__ngram_range=(1, 2);, score=0.749 total time= 1.9min
# [CV 5/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.6, vect__ngram_range=(1, 2);, score=0.710 total time= 1.9min
# [CV 1/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.6, vect__ngram_range=(1, 3);, score=0.646 total time= 2.5min
# [CV 2/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.6, vect__ngram_range=(1, 3);, score=0.669 total time= 2.3min
# [CV 3/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.6, vect__ngram_range=(1, 3);, score=0.627 total time= 2.5min
# [CV 4/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.6, vect__ngram_range=(1, 3);, score=0.678 total time= 2.4min
# [CV 5/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.6, vect__ngram_range=(1, 3);, score=0.641 total time= 2.5min
# [CV 1/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.7, vect__ngram_range=(1, 1);, score=0.788 total time= 1.0min
# [CV 2/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.7, vect__ngram_range=(1, 1);, score=0.784 total time= 1.1min
# [CV 3/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.7, vect__ngram_range=(1, 1);, score=0.741 total time= 1.0min
# [CV 4/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.7, vect__ngram_range=(1, 1);, score=0.814 total time= 1.0min
# [CV 5/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.7, vect__ngram_range=(1, 1);, score=0.776 total time=  50.2s
# [CV 1/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.7, vect__ngram_range=(1, 2);, score=0.734 total time= 1.9min
# [CV 2/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.7, vect__ngram_range=(1, 2);, score=0.735 total time= 2.0min
# [CV 3/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.7, vect__ngram_range=(1, 2);, score=0.689 total time= 1.9min
# [CV 4/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.7, vect__ngram_range=(1, 2);, score=0.764 total time= 1.9min
# [CV 5/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.7, vect__ngram_range=(1, 2);, score=0.713 total time= 1.9min
# [CV 1/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.7, vect__ngram_range=(1, 3);, score=0.680 total time= 2.5min
# [CV 2/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.7, vect__ngram_range=(1, 3);, score=0.686 total time= 2.4min
# [CV 3/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.7, vect__ngram_range=(1, 3);, score=0.647 total time= 2.4min
# [CV 4/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.7, vect__ngram_range=(1, 3);, score=0.699 total time= 2.4min
# [CV 5/5] END SVM__C=50, SVM__kernel=poly, vect__max_df=0.7, vect__ngram_range=(1, 3);, score=0.666 total time= 2.5min
# [CV 1/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.3, vect__ngram_range=(1, 1);, score=0.851 total time=  49.7s
# [CV 2/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.3, vect__ngram_range=(1, 1);, score=0.839 total time=  49.3s
# [CV 3/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.3, vect__ngram_range=(1, 1);, score=0.826 total time=  49.4s
# [CV 4/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.3, vect__ngram_range=(1, 1);, score=0.847 total time=  48.9s
# [CV 5/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.3, vect__ngram_range=(1, 1);, score=0.846 total time=  49.4s
# [CV 1/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.3, vect__ngram_range=(1, 2);, score=0.867 total time= 1.6min
# [CV 2/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.3, vect__ngram_range=(1, 2);, score=0.865 total time= 1.6min
# [CV 3/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.3, vect__ngram_range=(1, 2);, score=0.844 total time= 1.6min
# [CV 4/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.3, vect__ngram_range=(1, 2);, score=0.871 total time= 1.6min
# [CV 5/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.3, vect__ngram_range=(1, 2);, score=0.869 total time= 1.6min
# [CV 1/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.3, vect__ngram_range=(1, 3);, score=0.866 total time= 2.1min
# [CV 2/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.3, vect__ngram_range=(1, 3);, score=0.868 total time= 2.1min
# [CV 3/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.3, vect__ngram_range=(1, 3);, score=0.841 total time= 2.1min
# [CV 4/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.3, vect__ngram_range=(1, 3);, score=0.879 total time= 2.1min
# [CV 5/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.3, vect__ngram_range=(1, 3);, score=0.861 total time= 2.1min
# [CV 1/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.4, vect__ngram_range=(1, 1);, score=0.851 total time=  51.4s
# [CV 2/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.4, vect__ngram_range=(1, 1);, score=0.841 total time=  51.0s
# [CV 3/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.4, vect__ngram_range=(1, 1);, score=0.828 total time=  50.9s
# [CV 4/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.4, vect__ngram_range=(1, 1);, score=0.856 total time=  50.9s
# [CV 5/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.4, vect__ngram_range=(1, 1);, score=0.844 total time=  51.4s
# [CV 1/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.4, vect__ngram_range=(1, 2);, score=0.863 total time= 1.6min
# [CV 2/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.4, vect__ngram_range=(1, 2);, score=0.862 total time= 1.6min
# [CV 3/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.4, vect__ngram_range=(1, 2);, score=0.848 total time= 1.6min
# [CV 4/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.4, vect__ngram_range=(1, 2);, score=0.872 total time= 1.6min
# [CV 5/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.4, vect__ngram_range=(1, 2);, score=0.859 total time= 1.6min
# [CV 1/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.4, vect__ngram_range=(1, 3);, score=0.857 total time= 2.1min
# [CV 2/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.4, vect__ngram_range=(1, 3);, score=0.861 total time= 2.1min
# [CV 3/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.4, vect__ngram_range=(1, 3);, score=0.846 total time= 2.1min
# [CV 4/5] END SVM__C=50, SVM__kernel=rbf, vect__max_df=0.4, vect__ngram_range=(1, 3);, score=0
with: {'SVM__C': 50, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 2)}
# 0.740895 (0.005465) with: {'SVM__C': 50, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 3)}
# 0.730183 (0.008836) with: {'SVM__C': 50, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 1)}
# 0.745894 (0.007452) with: {'SVM__C': 50, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 2)}
# 0.736468 (0.010577) with: {'SVM__C': 50, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 3)}
# 0.685331 (0.008030) with: {'SVM__C': 50, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 1)}
# 0.713183 (0.005618) with: {'SVM__C': 50, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 2)}
# 0.711471 (0.010329) with: {'SVM__C': 50, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 3)}
# 0.672334 (0.011792) with: {'SVM__C': 50, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 1)}
# 0.697330 (0.009113) with: {'SVM__C': 50, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 2)}
# 0.701044 (0.009912) with: {'SVM__C': 50, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 3)}
# 0.812459 (0.015212) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 1)}
# 0.765330 (0.049019) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 2)}
# 0.664915 (0.045650) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 3)}
# 0.785177 (0.019247) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 1)}
# 0.734474 (0.028537) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 2)}
# 0.681767 (0.029435) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 3)}
# 0.792748 (0.019798) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 1)}
# 0.744613 (0.022557) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 2)}
# 0.694480 (0.031265) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 3)}
# 0.789462 (0.027291) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 1)}
# 0.753468 (0.027243) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 2)}
# 0.712333 (0.030072) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 3)}
# 0.774034 (0.020166) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 1)}
# 0.728897 (0.018912) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 2)}
# 0.689333 (0.016589) with: {'SVM__C': 10, 'SVM__kernel': 'poly', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 3)}
# 0.842878 (0.007383) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 1)}
# 0.862733 (0.009732) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 2)}
# 0.863162 (0.012651) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 3)}
# 0.846450 (0.007635) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 1)}
# 0.860877 (0.007837) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 2)}
# 0.859163 (0.009192) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 3)}
# 0.845879 (0.008761) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 1)}
# 0.860163 (0.008422) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 2)}
# 0.860734 (0.009225) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 3)}
# 0.846737 (0.007891) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 1)}
# 0.860306 (0.008751) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 2)}
# 0.861448 (0.010449) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 3)}
# 0.848165 (0.008503) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 1)}
# 0.861020 (0.007680) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 2)}
# 0.863877 (0.007976) with: {'SVM__C': 10, 'SVM__kernel': 'rbf', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 3)}
# 0.770320 (0.008573) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 1)}
# 0.798458 (0.008344) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 2)}
# 0.827883 (0.005262) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 3)}
# 0.745752 (0.010386) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 1)}
# 0.780889 (0.010677) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 2)}
# 0.799029 (0.006519) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 3)}
# 0.735039 (0.009353) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 1)}
# 0.770033 (0.007567) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 2)}
# 0.787745 (0.006437) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 3)}
# 0.689188 (0.008190) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 1)}
# 0.723467 (0.006649) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 2)}
# 0.736609 (0.011344) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 3)}
# 0.675191 (0.010456) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 1)}
# 0.707328 (0.008027) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 2)}
# 0.722183 (0.010483) with: {'SVM__C': 10, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 3)}
# 0.657893 (0.051788) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 1)}
# 0.564486 (0.022085) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 2)}
# 0.532351 (0.009794) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 3)}
# 0.728901 (0.043546) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 1)}
# 0.627893 (0.067889) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 2)}
# 0.568905 (0.048845) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 3)}
# 0.726047 (0.031506) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 1)}
# 0.660905 (0.052927) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 2)}
# 0.599904 (0.057932) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 3)}
# 0.754470 (0.037499) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 1)}
# 0.693901 (0.051649) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 2)}
# 0.620901 (0.048500) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 3)}
# 0.675193 (0.027558) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 1)}
# 0.657911 (0.039380) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 2)}
# 0.655628 (0.054990) with: {'SVM__C': 1.0, 'SVM__kernel': 'poly', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 3)}
# 0.850735 (0.007159) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 1)}
# 0.858305 (0.009176) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 2)}
# 0.853734 (0.009708) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 3)}
# 0.850307 (0.006111) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 1)}
# 0.853734 (0.006949) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 2)}
# 0.849021 (0.008342) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 3)}
# 0.849879 (0.005467) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 1)}
# 0.852735 (0.006018) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 2)}
# 0.849306 (0.007722) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 3)}
# 0.848879 (0.006816) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 1)}
# 0.852592 (0.007559) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 2)}
# 0.850164 (0.008282) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 3)}
# 0.850735 (0.002607) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 1)}
# 0.854021 (0.003985) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 2)}
# 0.851021 (0.010338) with: {'SVM__C': 1.0, 'SVM__kernel': 'rbf', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 3)}
# 0.837310 (0.005741) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 1)}
# 0.863591 (0.006206) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 2)}
# 0.866019 (0.007538) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.3, 'vect__ngram_range': (1, 3)}
# 0.811742 (0.004961) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 1)}
# 0.862306 (0.002911) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 2)}
# 0.865591 (0.004016) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.4, 'vect__ngram_range': (1, 3)}
# 0.795744 (0.005901) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 1)}
# 0.852879 (0.005079) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 2)}
# 0.866162 (0.004475) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.5, 'vect__ngram_range': (1, 3)}
# 0.725612 (0.008530) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 1)}
# 0.797601 (0.009679) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 2)}
# 0.837881 (0.003657) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.6, 'vect__ngram_range': (1, 3)}
# 0.707471 (0.012806) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 1)}
# 0.777317 (0.007822) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 2)}
# 0.821312 (0.005830) with: {'SVM__C': 1.0, 'SVM__kernel': 'sigmoid', 'vect__max_df': 0.7, 'vect__ngram_range': (1, 3)}

# %% [markdown]
# # trainingFinal

# %%
#Defining input and target variable
X = df['Processed_Reviews']
y = df['sentiment']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
#Vectorization and Bag of words method with default parameters
count_vect = CountVectorizer(max_df = 0.6, ngram_range = (1, 2)).fit(df['Processed_Reviews'].values.astype('U'))
bow_train = count_vect.transform(X_train.values.astype('U'))
bow_test = count_vect.transform(X_test.values.astype('U'))

# %%
SVM = SVC(C=50, kernel='rbf')

# %%
SVM.fit(bow_train, y_train)
# Out:
# SVC(C=50)

# %%
#perform classification and prediction on samples in tf_test
predicted_SVM = SVM.predict(bow_test)
print(classification_report(y_test, predicted_SVM))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.88      5035
#            1       0.87      0.90      0.89      4965
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000

# %%
#saving the model
pickle.dump(SVM, open('SVM_model', 'wb'))

# %%
pickle.dump(count_vect, open('count_vect', 'wb'))

# %%
#loading the model
#loaded_SVM = pickle.load(open('SVM_model', 'rb'))

# %% [markdown]
# # Test

# %%
test = ['useless']
test = count_vect.transform(test).toarray()
print(SVM.predict(test))
# Out:
# [0]

# %%
test = ['good movie']
test = count_vect.transform(test).toarray()
print(loaded_SVM.predict(test))
# Out:
# [1]
